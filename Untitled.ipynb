# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imshow, imread
from skimage.transform import downscale_local_mean

image = imread('sample_2.jpg')
print(image.shape)
print(image)

import cv2
import numpy as np

#read image
src = cv2.imread('sample_2.jpg', cv2.IMREAD_UNCHANGED)
print(src.shape)

# assign blue channel to zeros
src[:,:,0] = np.zeros([src.shape[0], src.shape[1]])

#save image
src.show()
# Out:
# (268, 271, 3)
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [213 213 213]
#   [254 254 254]
#   [255 255 255]]
#
#  [[254 254 254]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [213 213 213]
#   [254 254 254]
#   [255 255 255]]
#
#  [[254 254 254]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [213 213 213]
#   [254 254 254]
#   [255 255 255]]]
# ----------------------------------------------------------------
# ModuleNotFoundError            Traceback (most recent call last)
# <ipython-input-15-33aac3059540> in <module>
#       8 print(image)
#       9
# ---> 10 import cv2
# ...

# %%
from PIL import Image
rgba_image  = Image.open('laberinto.png')
rgba_image .load()
background = Image.new("RGB", rgba_image.size, (255, 255, 255))
background.paste(rgba_image, mask = rgba_image.split()[3])
background.save("sample_2.jpg", "JPEG", quality=100)

rgb_image = Image.open("sample_2.jpg")
rgb_image.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=271x268 at 0x7F984F82D630>
